# %%
from io import open
import unicodedata
import string
import re
import random

class Language:
    def __init__(self, name):
        '''
        class to get index2word, word2index, wordcount of a language
        '''
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2 
    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)
    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %%
def unicodeToAscii(s):
    '''
    to remove all unicodes and foreign language's accent characters
    '''
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

def process_sentence(s):
    '''
    remove other chars and lowecase the sentence.
    '''
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    return s

# %%
def readLangs(lang1, lang2, reverse=False):
    dataset = 'data/cat.txt'
    lines = open(dataset, encoding='utf-8').\
        read().strip().split('\n')
    pairs = [[process_sentence(s) for s in l.split('\t')] for l in lines]
    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Language(lang2)
        output_lang = Language(lang1)
    else:
        input_lang = Language(lang1)
        output_lang = Language(lang2)
    return input_lang, output_lang, pairs

# %%
# I want to use the function with lang1 = eng, lang2 = cat and the dataset = data/cat.txt
input_lang, output_lang, pairs = readLangs('eng', 'cat', False)

# %%
pairs
# Out:
# [['wow !', 'carai !'],
#  ['wait .', 'espera t .'],
#  ['i left .', 'm en vaig anar .'],
#  ['really ?', 'de veritat ?'],
#  ['thanks !', 'gracies !'],
#  ['thanks .', 'gracies !'],
#  ['get out !', 'surtiu .'],
#  ['get out !', 'fora !'],
#  ['get out .', 'surtiu .'],
#  ['goodbye !', 'adeu !'],
#  ['i agree .', 'hi estic d acord .'],
#  ['hurry up .', 'afanya t .'],
#  ['too late .', 'massa tard .'],
#  ['i ll walk .', 'm anire caminant .'],
#  ['thank you .', 'gracies !'],
#  ['can i help ?', 'puc ajudar ?'],
#  ['i envy him .', 'l envejo .'],
#  ['i love you .', 't estimo .'],
#  ['that s tom .', 'aixi es en tom .'],
#  ['time flies .', 'el temps vola .'],
#  ['we saw you .', 'vos vam vore .'],
#  ['i like both .', 'm agraden ambdos .'],
#  ['i like cats .', 'm agraden els gats'],
#  ['i will walk .', 'm anire caminant .'],
#  ['i ll try it .', 'la provare .'],
#  ['i m too .', 'jo tambe tinc anys .'],
#  ['i m a vegan .', 'jo soc vega'],
#  ['i m at home .', 'estic a casa .'],
#  ['i m stuffed .', 'estic molt tip .'],
#  ['make a wish .', 'demana un desig'],
#  ['money talks .', 'qui paga mana .'],
#  ['we love you .', 't estimem .'],
#  ['we love you .', 'us estimem .'],
#  ['where is he ?', 'on es ?'],
#  ['who are you ?', 'qui ets tu ?'],
#  ['who are you ?', 'qui es voste ?'],
#  ['who are you ?', 'qui ets ?'],
#  ['who are you ?', 'qui sou ?'],
#  ['come with us .', 'vine amb nosaltres .'],
#  ['he has a dog .', 'ell te un gos .'],
#  ['i ve checked .', 'ho he comprovat .'],
#  ['she stood up .', 'ella es va aixecar .'],
#  ['tom is vegan .', 'el tom es vega'],
#  ['we know that .', 'ho sabem .'],
#  ['we need help .', 'ens cal ajuda .'],
#  ['we need help .', 'necessitem ajuda .'],
#  ['we re vegans .', 'nosaltres som vegans'],
#  ['any questions ?', 'alguna pregunta ?'],
#  ['are you happy ?', 'ets felic ?'],
#  ['bats scare me .', 'em fan por els ratpenats .'],
#  ['hi everybody .', 'hola a tots .'],
#  ['i hate coffee .', 'detesto el cafe .'],
#  ['i m a redhead .', 'soc pel roja .'],
#  ['i m desperate .', 'estic desesperat .'],
#  ['i m very full .', 'estic molt tip .'],
#  ['let me try it .', 'deixa m intentar ho .'],
#  ['she hated him .', 'ella l odiava .'],
#  ['use your fist .', 'fes servir el teu puny .'],
#  ['you look good .', 'tens bona cara .'],
#  ['you look good .', 'fas bona cara .'],
#  ['you look good .', 'fas bon aspecte .'],
#  ['are you asleep ?', 'dorms ?'],
#  ['are you asleep ?', 't has adormit ?'],
#  ['are you asleep ?', 'dormiu ?'],
#  ['are you asleep ?', 'us heu adormit ?'],
#  ['are you crying ?', 'estas plorant ?'],
#  ['are you crying ?', 'que plores ?'],
#  ['are you insane ?', 'estas boig ?'],
#  ['can i help you ?', 'puc ajudar ?'],
#  ['don t cry tom .', 'no ploris tom .'],
#  ['happy new year !', 'bon any nou !'],
#  ['i am a redhead .', 'soc pel roja .'],
#  ['i hate karaoke .', 'detesto el karaoke .'],
#  ['i like to walk .', 'm agrada caminar .'],
#  ['i like walking .', 'm agrada caminar .'],
#  ['i need a stamp .', 'necessito un segell .'],
#  ['i saw him jump .', 'el vaig veure saltar .'],
#  ['is that a bear ?', 'es aquest un os ?'],
#  ['leave me alone !', 'deixa m en pau !'],
#  ['she s pregnant .', 'ella esta embarassada .'],
#  ['she s pregnant .', 'esta embarassada .'],
#  ['she s pregnant .', 'ella esta prenyada .'],
#  ['she s pregnant .', 'esta prenyada .'],
#  ['they hated tom .', 'odiaven en tom .'],
#  ['this is a fish .', 'aixo es un peix .'],
#  ['this is a fish .', 'aco es un peix .'],
#  ['this is a pear .', 'aixo es una pera .'],
#  ['tom can t swim .', 'en tom no sap nedar .'],
#  ['we re all safe .', 'estem tots be .'],
#  ['who painted it ?', 'qui ho ha pintat ?'],
#  ['whose are they ?', 'de qui son ?'],
#  ['congratulations !', 'l enhorabona !'],
#  ['didn t you know ?', 'no ho sabies ?'],
#  ['her book is red .', 'el seu llibre es roig .'],
#  ['i didn t say it .', 'no ho he dit pas .'],
#  ['i felt the same .', 'em sentia igual .'],
#  ['i have two cats .', 'tinc dos gats .'],
#  ['i made tom wait .', 'he fet esperar en tom'],
#  ['it s your fault .', 'es culpa teva .'],
#  ['she admired him .', 'ella l admirava .'],
#  ['tom turned blue .', 'el tom va posar se blau .'],
#  ['we re not tired .', 'no ens hem cansat .'],
#  ['what great news !', 'quina bona nova !'],
#  ['who are you all ?', 'qui sou tots vosaltres ?'],
#  ['who are you all ?', 'qui sou totes vosaltres ?'],
#  ['you let me down .', 'm has decebut .'],
#  [' is less than .', ' son menys que .'],
#  ['are you an idiot ?', 'ets idiota ?'],
#  ['are you blushing ?', 'que t enrojoles ?'],
#  ['are you finished ?', 'has acabat ?'],
#  ['do you wanna bet ?', 'apostes ?'],
#  ['go to sleep tom .', 'ves a dormir tom'],
#  ['go to sleep tom .', 'a dormir tom .'],
#  ['go to sleep tom .', 'ves al llit tom .'],
#  ['go to sleep tom .', 'cap al llit tom .'],
#  ['have you had tea ?', 'ja heu sopat ?'],
#  ['he hates spiders .', 'ell avorreix les aranyes .'],
#  ['here is your bag .', 'aqui es la teva bossa .'],
#  ['here is your bag .', 'aci esta la teua bossa .'],
#  ['here is your bag .', 'aci tens la teua bossa .'],
#  ['hope hasn t died .', 'espero que no hagi mort .'],
#  ['i am now on duty .', 'ara estic de servei .'],
#  ['i ate the cheese .', 'em vaig menjar el formatge .'],
#  ['i hate chemistry .', 'odio la quimica .'],
#  ['i have a problem .', 'tinc un problema .'],
#  ['i have a problem .', 'tinc un maldecap .'],
#  ['i have no family .', 'no tinc familia .'],
#  ['i work in a bank .', 'jo treballo a un banc .'],
#  ['i wrote a letter .', 'vaig escriure una carta .'],
#  ['i m already late .', 'ja faig tard .'],
#  ['i m not a doctor .', 'jo no soc metge .'],
#  ['is he still here ?', 'ell encara es aqui ?'],
#  ['it s not so easy .', 'no es tan facil .'],
#  ['let go of my arm .', 'deixa m anar el brac .'],
#  ['she lives nearby .', 'viu aqui prop .'],
#  ['they are artists .', 'ells son artistes .'],
#  ['they re my books .', 'son els meus llibres .'],
#  ['this is your dog .', 'aquest es el teu gos .'],
#  ['tom isn t hungry .', 'tom no te fam .'],
#  ['tom walked alone .', 'en tom caminava sol .'],
#  ['tom writes books .', 'en tom escriu llibres .'],
#  ['we want a lawyer .', 'volem un advocat .'],
#  ['what is going on ?', 'que hi ha ?'],
#  ['what is going on ?', 'que passa ?'],
#  ['who are you with ?', 'amb qui estas ?'],
#  ['who are you with ?', 'amb qui esteu ?'],
#  ['why are you here ?', 'perque estas aqui ?'],
#  ['are you going out ?', 'sortireu ?'],
#  ['do you want to go ?', 'et vols anar ?'],
#  ['do you wish to go ?', 'et vols anar ?'],
#  ['don t be like tom .', 'no siguis com en tom .'],
#  ['everybody laughed .', 'tothom rigue .'],
#  ['have you seen her ?', 'l has vista ?'],
#  ['he went back home .', 'ell va tornar a casa .'],
#  ['i also kissed tom .', 'jo tambe vaig petonejar en tom .'],
#  ['i have an earache .', 'tinc otitis .'],
#  ['i have black eyes .', 'tinc els ulls negres .'],
#  ['i know those bars .', 'jo conec aqueixos bars .'],
#  ['i think he did it .', 'crec que ho va fer ell .'],
#  ['i want to see you .', 'vull veure t .'],
#  ['i will go on foot .', 'm anire caminant .'],
#  ['i m a bit nervous .', 'estic un poc nervios .'],
#  ['i m a salesperson .', 'soc venedor .'],
#  ['i m always hungry .', 'sempre tinc fam .'],
#  ['i m always hungry .', 'sempre tinc gana .'],
#  ['i m not a teacher .', 'no soc professora .'],
#  ['let me have a try .', 'deixa m intentar ho .'],
#  ['nobody is perfect .', 'ningu es perfecte .'],
#  ['she has long hair .', 'ella te el cabell llarg .'],
#  ['she hates carrots .', 'ella odia les carrotes .'],
#  ['she hates carrots .', 'ella odia les pastanagues .'],
#  ['she hates carrots .', 'ella odia les safanories .'],
#  ['she hates running .', 'ella odia correr .'],
#  ['silence is golden .', 'callar val tant com l or .'],
#  ['that book is mine .', 'aquell llibre es meu .'],
#  ['that s ridiculous !', 'allo es ridicul !'],
#  ['that s ridiculous .', 'allo es ridicul .'],
#  ['they re my guests .', 'son els meus convidats .'],
#  ['tom chickened out .', 'en tom es va acollonir .'],
#  ['tom chickened out .', 'en tom es va cagar .'],
#  ['tom chickened out .', 'a en tom li va agafar cangueli .'],
#  ['tom doesn t drink .', 'tom no beu .'],
#  ['tom has a podcast .', 'en tom te un podcast .'],
#  ['tom hates himself .', 'en tom s odia a si mateix .'],
#  ['tom hates himself .', 'en tom s odia .'],
#  ['tom hates himself .', 'en tom s odia a ell mateix .'],
#  ['tom is ridiculous .', 'en tom es ridicul .'],
#  ['tom lacks courage .', 'a en tom li falta coratge .'],
#  ['we re watching tv .', 'estem mirant la televisio .'],
#  ['why is snow white ?', 'per que es blanca la neu ?'],
#  ['you can trust him .', 'pots confiar en ell .'],
#  ['you need to hurry .', 't has d afanyar .'],
#  ['you weren t wrong .', 'no estaves equivocat .'],
#  ['you re a good boy .', 'ets un bon noi .'],
#  ['you re ridiculous .', 'ets ridicul .'],
#  ['you re ridiculous .', 'ets ridicula .'],
#  ['all men are mortal .', 'tots els homes son mortals .'],
#  ['are you hungry now ?', 'tens fam ara ?'],
#  ['are you hungry now ?', 'teniu fam ara ?'],
#  ['are you hungry now ?', 'ara tens fam ?'],
#  ['come along with me .', 'acompanya m .'],
#  ['do it by all means .', 'fes ho com sigui .'],
#  ['do it by all means .', 'fes ho peti qui peti .'],
#  ['everyone loves him .', 'tots l estimen .'],
#  ['exercise every day .', 'fes exercici cada dia .'],
#  ['he is a clever boy .', 'es un noi despert .'],
#  ['he lost his memory .', 'va perdre la memoria .'],
#  ['i already said yes .', 'ja he dit que si .'],
#  ['i don t have a cat .', 'no tinc cap gat .'],
#  ['i don t want sugar .', 'no vull sucre .'],
#  ['i have lost my key .', 'he perdut la meva clau .'],
#  ['i made her a dress .', 'li vaig fer un vestit .'],
#  ['i want to meet you .', 'vull veure t .'],
#  ['i wrote a cookbook .', 'vaig escriure un llibre de cuina .'],
#  ['i m gaining weight .', 'estic guanyant pes .'],
#  ['is that real money ?', 'aixo son diners de veritat ?'],
#  ['is this book yours ?', 'aquest llibre es teu ?'],
#  ['it was a nightmare .', 'va ser un malson .'],
#  ['it was an easy win .', 'va ser una victoria facil .'],
#  ['it s not difficult .', 'no es pas dificil .'],
#  ['it s very hot here .', 'aqui fa molta calor .'],
#  ['it s very symbolic .', 'es molt simbolic .'],
#  ['it s very symbolic .', 'es molt simbolica .'],
#  ['mary is a feminist .', 'la maria es feminista .'],
#  ['my mother is angry .', 'la meva mare esta empipada .'],
#  ['shut up and listen !', 'calla i escolta !'],
#  ['shut up and listen .', 'calla i escolta !'],
#  ['stay out of my way .', 'fora del meu cami !'],
#  ['that s pure racism .', 'aixo es racisme pur !'],
#  ['the water was warm .', 'l aigua estava calenta .'],
#  ['this coat fits you .', 'aquest abric et queda be .'],
#  ['this is ridiculous !', 'aixo es ridicul !'],
#  ['this is ridiculous .', 'aixo es ridicul .'],
#  ['this isn t for you .', 'aixo no es per a tu .'],
#  ['tom is a silly man .', 'en tom es un ximplet .'],
#  ['we look ridiculous .', 'ens veiem ridicules .'],
#  ['we look ridiculous .', 'ens veiem ridiculs .'],
#  ['we ll convince tom .', 'convencerem en tom .'],
#  ['what awful weather !', 'quin temps tan dolent !'],
#  ['what s the problem ?', 'quin problema hi ha ?'],
#  ['what s your secret ?', 'quin es el teu secret ?'],
#  ['who has a question ?', 'algu te alguna pregunta ?'],
#  ['are you a policeman ?', 'ets policia ?'],
#  ['europe is in crisis .', 'europa esta en crisi .'],
#  ['everybody loves him .', 'tots l estimen .'],
#  ['have a good weekend !', 'bon cap de setmana !'],
#  ['have you had dinner ?', 'ja heu sopat ?'],
#  ['he went to the shop .', 'ell va anar a la tenda .'],
#  ['he ll return at six .', 'tornara a les sis .'],
#  ['he s the oldest son .', 'ell es el fill gran .'],
#  ['i can see the light .', 'puc veure la llum .'],
#  ['i drank all my milk .', 'vaig beure m tota la meva llet .'],
#  ['i like taking walks .', 'm agrada caminar .'],
#  ['i want to stay here .', 'vull quedar me aqui .'],
#  ['i d like to go home .', 'vull anar a casa .'],
#  ['i ll call him later .', 'li cridare mes tard .'],
#  ['i ve got a question .', 'tinc una pregunta .'],
#  ['she has a white cat .', 'ella te un gat blanc .'],
#  ['she raised her hand .', 'ella va aixecar la ma .'],
#  ['she raised her hand .', 'ella va alcar la ma .'],
#  ['she raised her hand .', 'ella alca la ma .'],
#  ['she raised her hand .', 'va alcar la ma .'],
#  ['that bottle is full .', 'aquella ampolla es plena .'],
#  ['the bicycle is mine .', 'la bicicleta es meva .'],
#  ['these are our books .', 'son els nostres llibres .'],
#  ['they were satisfied .', 'estaven satisfets .'],
#  ['they were satisfied .', 'estaven cofois .'],
#  ['those are our books .', 'son els nostres llibres .'],
#  ['what would you like ?', 'que desitja voste ?'],
#  ['where are you going ?', 'a on vas ?'],
#  ['who let you come in ?', 'qui t ha deixat entrar ?'],
#  ['who let you come in ?', 'qui us ha deixat entrar ?'],
#  ['who let you come in ?', 'qui us ha deixat passar ?'],
#  ['who let you come in ?', 'qui t ha deixat passar ?'],
#  ['you disappointed me .', 'm has decebut .'],
#  ['your father is tall .', 'ton pare es alt .'],
#  ['are you afraid of me ?', 'que tens por de mi ?'],
#  ['are you following me ?', 'm estas seguint ?'],
#  ['birds fly in the sky .', 'els ocells volen pel cel .'],
#  ['can he speak english ?', 'que parla angles ell ?'],
#  ['didn t you know that ?', 'no ho sabies ?'],
#  ['do you have a camera ?', 'tens camera fotografica ?'],
#  ['do you live in tokyo ?', 'vius a tokyo ?'],
#  ['do you want to leave ?', 'et vols anar ?'],
#  ['don t worry about me .', 'no et preocupis per mi .'],
#  ['fish live in the sea .', 'els peixos viuen al mar .'],
#  ['good night everyone !', 'bona nit a tothom !'],
#  ['he is a good athlete .', 'ell es un bon atleta .'],
#  ['he knows how to swim .', 'ell sap nedar .'],
#  ['he looked very happy .', 'ell semblava molt felic .'],
#  ['i bought some stamps .', 'vaig comprar alguns segells .'],
#  ['i called my attorney .', 'vaig trucar la meva advocada .'],
#  ['i called my attorney .', 'vaig trucar el meu advocat .'],
#  ['i dislike big cities .', 'no m agraden les ciutats grans .'],
#  ['i don t want to work .', 'no vull treballar .'],
#  ['i have a sore throat .', 'tinc mal de coll .'],
#  ['i have two daughters .', 'tinc dues filles .'],
#  ['i waited over a week .', 'vaig esperar mes d una setmana .'],
#  ['i wasn t asking that .', 'no he preguntat aixo .'],
#  ['i m an office worker .', 'soc un oficinista .'],
#  ['i m glad you re here .', 'm alegra que estigues aci .'],
#  ['i m glad you re here .', 'm alegra que estigueu aci .'],
#  ['is that your bicycle ?', 'esta es la teua bicicleta ?'],
#  ['it is free of charge .', 'es gratuit .'],
#  ['it s a piece of cake .', 'aixo es bufar i fer ampolles .'],
#  ['it s really annoying .', 'es realment molest .'],
#  ['many trees fell down .', 'van caure molts arbres .'],
#  ['she sent me a letter .', 'ella em va enviar una carta .'],
#  ['sorry for being late .', 'perdo pel retard .'],
#  ['that s a bright idea .', 'es una idea brillant .'],
#  ['the ground seems wet .', 'el sol sembla mullat .'],
#  ['the photo was a hoax .', 'la foto era un bluf .'],
#  ['the photo was a hoax .', 'la foto era una enganyifa .'],
#  ['the photo was a hoax .', 'la foto era un frau .'],
#  ['the photo was a hoax .', 'la foto era falsa .'],
#  ['they got off the bus .', 'ells van baixar de l autobus .'],
#  ['tom always says that .', 'tom sempre diu aixo .'],
#  ['tom doesn t watch tv .', 'en tom no mira la tele .'],
#  ['tom looks ridiculous .', 'en tom es veu ridicul .'],
#  ['tom ran out of money .', 'en tom es va quedar sense cales .'],
#  ['we have a lot of fun .', 'ens divertim molt .'],
#  ['we re not the police .', 'no som la policia .'],
#  ['we ve all been there .', 'tots hi hem estat alla .'],
#  ['we ve all been there .', 'tots hem viscut aixo .'],
#  ['what if they said no ?', 'que si diuen que no ?'],
#  ['where will tom sleep ?', 'on dormira en tom ?'],
#  ['who wrote the letter ?', 'qui ha escrit la carta ?'],
#  ['who s coming with me ?', 'qui ve amb mi ?'],
#  ['would you like to go ?', 'et vols anar ?'],
#  ['you can come with me .', 'pots venir amb mi .'],
#  ['you have to help her .', 'heu d ajudar la .'],
#  ['you re a good person .', 'eres bona persona .'],
#  ['your son is a genius .', 'el vostre fill es un geni .'],
#  ['are you expecting tom ?', 'esperes en tomas ?'],
#  ['brad pitt is an actor .', 'el brad pitt es un actor .'],
#  ['can you all come here ?', 'que podeu venir aqui ?'],
#  ['do you have two books ?', 'tens dos llibres ?'],
#  ['does he speak english ?', 'que parla angles ell ?'],
#  ['does he speak english ?', 'parla angles ?'],
#  ['does he speak english ?', 'ell parla angles ?'],
#  ['does your mother know ?', 'ho sap la teua mare ?'],
#  ['everything is perfect .', 'tot esta perfecte .'],
#  ['have you eaten dinner ?', 'ja heu sopat ?'],
#  ['have you ever done it ?', 'ho has fet mai ?'],
#  ['have you ever done it ?', 'ho has fet algun cop ?'],
#  ['his house was on fire .', 'la seva casa esta en flames .'],
#  ['i don t have time now .', 'ara no tinc temps .'],
#  ['i have to go to sleep .', 'he d anar a dormir .'],
#  ['i knew you were lying .', 'sabia que menties .'],
#  ['i know these students .', 'conec aquests estudiants .'],
#  ['i went to the station .', 'vaig anar a l estacio .'],
#  ['i d like some aspirin .', 'voldria una aspirina .'],
#  ['i d like to go abroad .', 'm agradaria anar a l estranger .'],
#  ['money opens all doors .', 'els diners obren totes les portes .'],
#  ['nobody understands me .', 'ningu no m enten .'],
#  ['she is a good swimmer .', 'es una bona nedadora .'],
#  ['thanks for everything .', 'merces per tot .'],
#  ['the girl said nothing .', 'la nena no va dir res .'],
#  ['they don t seem happy .', 'no semblen felicos .'],
#  ['those are empty words .', 'son paraules buides .'],
#  ['tom likes indian food .', 'a en tom li agrada el menjar indi .'],
#  ['tom looked ridiculous .', 'en tom es veia ridicul .'],
#  ['tom was afraid to die .', 'en tom temia la mort .'],
#  ['we have two daughters .', 'tenim dues filles .'],
#  ['we have yellow apples .', 'nosaltres tenim les pomes grogues .'],
#  ['what are you planning ?', 'que planeges ?'],
#  ['what horrible weather !', 'quin temps tan dolent !'],
#  ['what s inside the box ?', 'que hi ha a la caixa ?'],
#  ['what s inside the box ?', 'que hi ha dins la caixa ?'],
#  ['what s wrong with you ?', 'que et passa ?'],
#  ['who built the snowman ?', 'qui ha fet el ninot de neu ?'],
#  ['you should eat slower .', 'has de menjar mes a poc a poc .'],
#  ['you should ve stopped .', 't hauries d haver aturat .'],
#  ['you re taller than me .', 'ets mes alt que jo .'],
#  ['are you coming with us ?', 'vens amb nosaltres ?'],
#  ['are you falling for me ?', 't estas penjant de mi ?'],
#  ['can you guys come here ?', 'que podeu venir aqui ?'],
#  ['come whenever you like .', 'vingui quan vulgui .'],
#  ['come whenever you like .', 'veniu quan vulgueu .'],
#  ['come whenever you like .', 'vine quan vulguis .'],
#  ['did you have breakfast ?', 'ja has esmorzat ?'],
#  ['do you like this music ?', 't agrada aquesta musica ?'],
#  ['does the bus stop here ?', 'l autobus para aci ?'],
#  ['have you had breakfast ?', 'ja has esmorzat ?'],
#  ['i didn t buy this book .', 'no vaig comprar aquest llibre .'],
#  ['i think tom isn t home .', 'crec que en tom no esta a casa .'],
#  ['i think he has done it .', 'crec que ell ho ha fet .'],
#  ['i want to get a tattoo .', 'em vull tatuar .'],
#  ['i d like to rent a car .', 'voldria llogar un cotxe .'],
#  ['i ll find the solution .', 'hi trobare la solucio .'],
#  ['i m not angry with you .', 'no estic enfadada amb tu .'],
#  ['i m on my way to tom s .', 'estic de cami a can tom .'],
#  ['i m pretty tired today .', 'hui estic ben cansada .'],
#  ['i m sorry to hear that .', 'em sap greu escoltar aixo .'],
#  ['is rainwater drinkable ?', 'es pot beure l aigua de la pluja ?'],
#  ['it s not too hot today .', 'avui no fa gaire calor .'],
#  ['rainy days make me sad .', 'els dies de pluja em posen trist .'],
#  ['she can speak japanese .', 'ella sap parlar japones .'],
#  ['she gave him a present .', 'ella li va donar un regal .'],
#  ['they have enough money .', 'tenen prou diners .'],
#  ['they will not eat meat .', 'no menjaran carn .'],
#  ['tom wants to be famous .', 'tom vol ser famos .'],
#  ['we have to act quickly .', 'hem d actuar rapid .'],
#  ['who are you talking to ?', 'amb qui esteu parlant ?'],
#  ['are there any questions ?', 'hi ha preguntes ?'],
#  ['are you falling for tom ?', 't estas penjant d en tomas ?'],
#  ['ask me something easier .', 'pregunta m una cosa mes facil .'],
#  ['do you have a cellphone ?', 'tens un mobil ?'],
#  ['have you had dinner yet ?', 'ja heu sopat ?'],
#  ['he died three years ago .', 'va morir fa tres anys .'],
#  ['he s better than us all .', 'ell es millor que tots nosaltres .'],
#  ['i don t like big cities .', 'no m agraden les ciutats grans .'],
#  ['i felt like i would die .', 'sentia que em moriria .'],
#  ['i had a light breakfast .', 'vaig esmorzar lleuger .'],
#  ['i hope that i can do it .', 'espere poder ho fer .'],
#  ['i listened to her story .', 'vaig escoltar la historia d ella .'],
#  ['i remember what he said .', 'recordo el que va dir .'],
#  ['i think tom is reliable .', 'em penso que en tom es confiable .'],
#  ['i want to see the ocean .', 'vull veure l ocea .'],
#  ['i was warned about this .', 'hom me n va advertir .'],
#  ['i won t see him anymore .', 'no el veure mai mes .'],
#  ['i d like to get married .', 'm agradaria casar me .'],
#  ['i d like to go home now .', 'vull anar a casa ara .'],
#  ['i d like to go with tom .', 'm agradaria anar amb en tom .'],
#  ['i ll start this evening .', 'comencare aquest vespre .'],
#  ['i ll start this evening .', 'comencare esta vesprada .'],
#  ['i m not as brave as tom .', 'no soc tan valent com en tom .'],
#  ['i m sure of his success .', 'estic segur del seu exit .'],
#  ['i ve forgotten his name .', 'he oblidat el seu nom .'],
#  ['it was always like that .', 'sempre ha sigut aixi .'],
#  ['it s nice and cool here .', 'aqui fa fresca i s hi esta be .'],
#  ['many sailors can t swim .', 'molts mariners no saben nedar '],
#  ['my father quit drinking .', 'el meu pare va aturar de beure .'],
#  ['my father quit drinking .', 'mon pare va deixar de beure .'],
#  ['racism is still with us .', 'el racisme encara hi es amb nosaltres .'],
#  ['she helped me willingly .', 'ella em va ajudar de bon gust .'],
#  ['tell me when he returns .', 'avisa m quan torni .'],
#  ['tom is thirty years old .', 'tom te trenta anys .'],
#  ['we ll never do it again .', 'no ho farem mai mes .'],
#  ['we ll never do it again .', 'no ho tornarem a fer mai mes .'],
#  ['what a beautiful sunset !', 'quina posta de sol mes bonica !'],
#  ['what a beautiful sunset .', 'quina posta mes maca !'],
#  ['what a beautiful sunset .', 'quina posta de sol mes bonica .'],
#  ['where are our umbrellas ?', 'on estan els nostres paraigues ?'],
#  ['who are they talking to ?', 'amb qui estan parlant ?'],
#  ['who is this letter from ?', 'de qui es aquesta carta ?'],
#  ['would you draw me a map ?', 'em faries un mapa ?'],
#  ['you will miss the train .', 'perdras el tren .'],
#  ['you re everything to me .', 'tu ets tot per mi .'],
#  ['are you coming in or not ?', 'entres o no ?'],
#  ['are you going to save us ?', 'que ens salvareu ?'],
#  ['are you looking for work ?', 'busques feina ?'],
#  ['can i ask some questions ?', 'puc fer unes preguntes ?'],
#  ['can your mom drive a car ?', 'la teva mama sap conduir ?'],
#  ['can your mom drive a car ?', 'ta mare sap conduir ?'],
#  ['can your mom drive a car ?', 'la teua mare sap conduir un cotxe ?'],
#  ['can your mom drive a car ?', 'la vostra mare sap conduir ?'],
#  ['cats prefer fish to meat .',
#   'els gats s estimen mes el peix que la carn .'],
#  ['did you have a good time ?', 't ho vas passar be ?'],
#  ['do you have a cell phone ?', 'tens un mobil ?'],
#  ['do you have a smartphone ?', 'tens un mobil ?'],
#  ['don t ever do that again .', 'no ho facis mai mes .'],
#  ['fire is always dangerous .', 'el foc sempre es perillos .'],
#  ['gold s heavier than iron .', 'l or es mes pesat que el ferro .'],
#  ['have you had your dinner ?', 'ja heu sopat ?'],
#  ['have you had your supper ?', 'ja heu sopat ?'],
#  ['he fell and hurt his leg .', 'ell es va caure i es va fer mal a la cama .'],
#  ['he has never played golf .', 'ell no ha jugat mai al golf .'],
#  ['he looks like his father .', 'ell s assembla al seu pare .'],
#  ['he speaks five languages .', 'ell parla cinc idiomes .'],
#  ['he will be free tomorrow .', 'dema sira lliure .'],
#  ['i can t stand that noise .', 'no puc aguantar aquest soroll .'],
#  ['i didn t know what to do .', 'no sabia que fer .'],
#  ['i don t know her address .', 'no se la seva adreca .'],
#  ['i don t love you anymore .', 'ja no t estimo .'],
#  ['i made my son a new suit .', 'he fet un vestit nou per a mon fill .'],
#  ['i only have eyes for you .', 'aqui no veig ningu mes que tu .'],
#  ['i recognized him at once .', 'el vaig reconeixer de seguida .'],
#  ['i m talking on the phone .', 'parlo per telefon .'],
#  ['i m talking on the phone .', 'estic parlant per telefon .'],
#  ['i ve had a very hard day .', 'he tingut un dia molt dur .'],
#  ['it doesn t sound natural .', 'no sona natural .'],
#  ['my mother is always busy .', 'la meva mare sempre esta ocupada .'],
#  ['people want to feel safe .', 'la gent vol sentir se segura .'],
#  ['shall we go to the beach ?', 'anem a la platja ?'],
#  ['she had a strange hat on .', 'ella portava un barret estrany .'],
#  ['she sang better than him .', 'ella va cantar millor que ell .'],
#  ['that happened a year ago .', 'aixo va passar fa un any .'],
#  ['that s a beautiful dress .', 'aqueix es un vestit precios .'],
#  ['the room is rather small .', 'la cambra es forca petita .'],
#  ['this is perfectly normal .', 'aixo es del tot normal .'],
#  ['tom doesn t quite buy it .', 'en tom no s ho creu gaire .'],
#  ['tom is a history teacher .', 'en tom es un professor d historia .'],
#  ['tom might still be there .', 'en tom encara podria ser alla .'],
#  ['tom visited mary s grave .', 'en tom va visitar la tomba de la mary .'],
#  ['tom was discharged today .', 'al tom l han donat d alta avui .'],
#  ['tom was discharged today .', 'al tom l han acomiadat avui .'],
#  ['tom was discharged today .', 'al tom l han llicenciat avui .'],
#  ['tom was told not to wait .', 'al tom li van dir que no s esperes .'],
#  ['turn down the tv please .', 'baixa el volum del televisor .'],
#  ['turn the tv down please .', 'baixa el volum del televisor .'],
#  ['we must follow the rules .', 'hem de seguir les regles .'],
#  ['we re not going anywhere .', 'no anem enlloc .'],
#  ['what did tom ask you for ?', 'que t ha demanat en tom ?'],
#  ['what s happening tonight ?', 'que esta passant aquest nit ?'],
#  ['what s happening tonight ?', 'que passa aquesta nit ?'],
#  ['you are lost aren t you ?', 't has perdut no es aixi ?'],
#  ['you don t have to eat it .', 'voste no ha de menjar ho .'],
#  ['are you free this weekend ?', 'estas lliure este cap de setmana ?'],
#  ['can you delete this photo ?', 'pots esborrar aquesta foto ?'],
#  ['do you have any questions ?', 'alguna pregunta ?'],
#  ['do you listen to podcasts ?', 'escoltes podcasts ?'],
#  ['dogs bark and birds tweet .', 'els gossos borden i les aus piulen .'],
#  ['don t leave the door open .', 'no deixeu la porta oberta .'],
#  ['don t you have work today ?', 'avui no tens feina ?'],
#  ['everyone likes big pizzas .', 'a tothom li agraden les pizzes grans .'],
#  ['gold is heavier than iron .', 'l or es mes pesat que el ferro .'],
#  ['have you eaten dinner yet ?', 'ja heu sopat ?'],
#  ['have you eaten supper yet ?', 'ja heu sopat ?'],
#  ['i didn t suspect anything .', 'no vaig sospitar res .'],
#  ['i didn t suspect anything .', 'no sospitava res .'],
#  ['i have a coat but no hat .', 'tinc un abric pero cap barret .'],
#  ['i know that tom is nearby .', 'se que en tom esta a prop .'],
#  ['i like listening to music .', 'm agrada escoltar musica .'],
#  ['i like to listen to music .', 'm agrada escoltar musica .'],
#  ['i made a careless mistake .', 'vaig cometre una negligencia .'],
#  ['i think we ll go with you .', 'crec que hi anirem amb tu .'],
#  ['i think we ll go with you .', 'crec que ens en anirem amb tu .'],
#  ['i want to talk to tom now .', 'vull parlar amb en tom ara mateix .'],
#  ['i m busy so i can t help .', 'estic ocupat no puc ajudar te .'],
#  ['i m busy so i can t help .', 'estic ocupat no puc ajudar vos .'],
#  ['i m disappointed with you .', 'm has decebut .'],
#  ['i m locked out of my room .', 'estic atrapat fora de la meva cambra .'],
#  ['i m standing in the shade .', 'm estic dret a l ombra .'],
#  ['is racism a serious issue ?', 'el racisme es una questio seriosa ?'],
#  ['is racism a serious issue ?', 'el racisme es un assumpte serios ?'],
#  ['it can wait until morning .', 'no puc esperar fins al mati .'],
#  ['it s always been that way .', 'sempre ha sigut aixi .'],
#  ['my sister hit the jackpot .', 'a la meva germana li va tocar la grossa .'],
#  ['please turn off the light .', 'per favor apaga el llum .'],
#  ['racism is a serious issue .', 'el racisme es un problema serios .'],
#  ['that house belongs to him .', 'aquella casa li pertany .'],
#  ['that ll put you in danger .', 'aixo et posara en perill .'],
#  ['tom doesn t drive to work .', 'en tom no condueix a la feina .'],
#  ['tom told me the good news .', 'en tom m ha dit la bona nova .'],
#  ['tom told me the good news .', 'en tom m ha comunicat la bona noticia .'],
#  ['tom went to the cafeteria .', 'el tom va anar a la cafeteria .'],
#  ['we have to obey the rules .', 'hem de seguir les regles .'],
#  ['we may be late for school .', 'potser farem tard a l escola .'],
#  ['what a nice sounding word !', 'que be sona aquesta paraula !'],
#  ['where will you be staying ?', 'on t estaras ?'],
#  ['where will you be staying ?', 'on t allotjaras ?'],
#  ['where will you be staying ?', 'on et quedaras ?'],
#  ['where will you be staying ?', 'on us allotjareu ?'],
#  ['who buys this type of art ?', 'qui compra aquest tipus d art ?'],
#  ['you agree with tom right ?', 'estas d acord amb tom oi ?'],
#  ['you agree with tom right ?', 'esteu d acord amb tom veritat ?'],
#  ['you can stay here tonight .', 'pots passar la nit aqui .'],
#  ['you don t have to do this .', 'no has de fer ho .'],
#  ['you don t have to do this .', 'aixo no ho has de fer .'],
#  ['you still have to do that .', 'encara tens que fer allo .'],
#  ['could you tell me the time ?', 'em podries dir l hora ?'],
#  ['do they have any good news ?', 'tens bones noticies ?'],
#  ['do you come here every day ?', 'vens aqui cada dia ?'],
#  ['do you come here every day ?', 'veniu aci tots els dies ?'],
#  ['do you have a book to read ?', 'tens algun llibre per llegir ?'],
#  ['do you have a mobile phone ?', 'tens un mobil ?'],
#  ['do you know his birthplace ?', 'saps on va neixer ?'],
#  ['have you had breakfast yet ?', 'ja has esmorzat ?'],
#  ['how long has it been there ?', 'quant de temps hi ha estat ?'],
#  ['i can t solve that problem .', 'no puc solucionar aquell problema .'],
#  ['i don t have time to write .', 'no tinc temps per escriure .'],
#  ['i got along with everybody .', 'em portava be amb tothom .'],
#  ['i have to buy one tomorrow .', 'he de comprar ne un dema .'],
#  ['i just want to be near you .', 'nomes vull estar prop de tu .'],
#  ['i know he likes jazz music .', 'se que li agrada el jazz .'],
#  ['i ordered a pizza by phone .', 'vaig demanar una pizza per telefon .'],
#  ['i think he ll never return .', 'crec que mai no tornara .'],
#  ['i want to learn how to ski .', 'vull aprendre a esquiar .'],
#  ['i would like to rent a car .', 'voldria llogar un cotxe .'],
#  ['i d like to get some sleep .', 'voldria dormir una mica .'],
#  ['i d like to get some sleep .', 'm agradaria dormir una mica .'],
#  ['i d like to give it to tom .', 'm agradaria donar li ho a en tom .'],
#  ['i d like to go to the mall .', 'm agradaria anar al centre comercial .'],
#  ['i d rather do it by myself .', 'prefereixo fer lo pel meu compte .'],
#  ['i ll show you a few photos .', 't ensenyo un parell de fotos .'],
#  ['i m afraid i caught a cold .', 'em sembla que he agafat un constipat .'],
#  ['it s all you can really do .', 'es tot el que pots fer .'],
#  ['it s always been like that .', 'sempre ha sigut aixi .'],
#  ['life became very difficult .', 'la vida es va tornar molt dificil .'],
#  ['she and i are the same age .', 'ella i jo tenim la mateixa edat .'],
#  ['she s tom s younger sister .', 'es la germana petita d en tom .'],
#  ['she s tom s younger sister .', 'es la germana menuda de tom .'],
#  ['the bird s wing was broken .', 'l ala de l ocell estava trencada .'],
#  ['the bird s wing was broken .', 'l ocell tenia una ala trencada .'],
#  ['the bird s wing was broken .', 'el pardal tenia una ala trencada .'],
#  ['there were ten eggs in all .', 'hi havia deu ous en total .'],
#  ['there s no reason to worry .', 'no hi ha cap motiu per preocupar se .'],
#  ['things are not that simple .', 'les coses no son tan senzilles .'],
#  ['this lake s water is clean .', 'l aigua d aquest llac esta neta .'],
#  ['this store sells old books .', 'aquesta botiga ven llibres vells .'],
#  ['tom always drives too fast .', 'en tom sempre condueix massa rapid .'],
#  ['tom warned mary about john .', 'en tom adverti la maria d en joan .'],
#  ['tom works in a coffee shop .', 'en tom treballa en una cafeteria .'],
#  ['we have to go by the rules .', 'hem de seguir les regles .'],
#  ['we walked three kilometers .', 'vam caminar tres quilometres .'],
#  ['what really happened to us ?', 'que ens va passar realment ?'],
#  ['what really happened to us ?', 'que ens va passar en realitat ?'],
#  ['what would you like to eat ?', 'que voldras de menjar ?'],
#  ['where will tom be sleeping ?', 'on dormira en tom ?'],
#  ['where s tom going to sleep ?', 'on dormira en tom ?'],
#  ['which do you think is best ?', 'quin creus que es millor ?'],
#  ['which do you think is best ?', 'quina creus que es millor ?'],
#  ['you re not a child anymore .', 'ja no ets un nen .'],
#  ['your opinion is irrelevant .', 'la teua opinio es irrellevant .'],
#  ['are you asking me on a date ?', 'm estas proposant una cita ?'],
#  ['aren t you ever coming back ?', 'que no tornaras mai ?'],
#  ['but why is it all so secret ?', 'pero per que es tot tan secret ?'],
#  ['by the way how old are you ?', 'per cert quina edat tens ?'],
#  ['columbus discovered america .', 'colon va descobrir america .'],
#  ['come on it s not that hard .', 'vinga que no es tan complicat .'],
#  ['does tom still have a fever ?', 'en tom encara te febre ?'],
#  ['don t you like chinese food ?', 'no t agrada el menjar xines ?'],
#  ['france is in western europe .', 'franca es a l europa occidental .'],
#  ['he plays baseball every day .', 'juga al beisbol tots el dies .'],
#  ['he told me not to tell lies .', 'em va dir que no expliques mentides .'],
#  ['he wants a watch like yours .', 'vol un rellotge com el teu .'],
#  ['he s the one who touched me .', 'ell es el que em va tocar .'],
#  ['how long have you been here ?', 'quant de temps us heu estat aqui ?'],
#  ['i didn t pay tom to do that .', 'jo no vaig pagar el tom per fer allo .'],
#  ['i didn t pay tom to do that .', 'no vaig pagar el tom per fer ho .'],
#  ['i don t know if he knows it .', 'no se si ho sap .'],
#  ['i don t want to do it again .', 'no vull tornar ho a fer .'],
#  ['i know everything about you .', 'ho se tot de tu .'],
#  ['i like pizza with pineapple .', 'm agrada la pizza amb pinya .'],
#  ['i want to break up with you .', 'vull tallar amb tu .'],
#  ['i work at a language school .', 'treballo en una escola d idiomes .'],
#  ['i d like some sugar please .',
#   'm agradaria una mica de sucre si us plau .'],
#  ['i d like to get to know tom .', 'm agradaria coneixer en tom mes a fons .'],
#  ['i d like to go out with you .', 'm agradaria sortir amb tu .'],
#  ['i d like to go out with you .', 'voldria sortir amb tu .'],
#  ['i ll be back in ten minutes .', 'tornare en deu minuts .'],
#  ['i m sorry my father is out .',
#   'em sap greu pero el meu pare no es a casa .'],
#  ['i m the one who has the key .', 'jo soc qui te la clau .'],
#  ['i ve put on a little weight .', 'he guanyat una mica de pes .'],
#  ['is it going to snow tonight ?', 'que nevara avui al vespre ?'],
#  ['maybe tom asked mary to lie .',
#   'potser el tom li va demanar a la mary que mentis .'],
#  ['my dog has a very long tail .', 'el meu gos te una cua molt llarga .'],
#  ['racism today isn t so overt .',
#   'el racisme avui dia encara no ha acabat .'],
#  ['she saved a hundred dollars .', 'ella es va estalviar cent dolars .'],
#  ['take off your socks please .', 'sisplau lleva t els mitjons .'],
#  ['take off your socks please .', 'lleva t els calcetins per favor .'],
#  ['take off your socks please .', 'lleveu vos els calcetins per favor .'],
#  ['thank you for the other day .', 'gracies per l altre dia .'],
#  ['the evidence was against me .', 'l evidencia estava en contra meua .'],
#  ['there s just too much to do .', 'senzillament hi ha tant a fer .'],
#  ['they aren t my real parents .', 'ells no son els meus vertaders pares .'],
#  ['they say that love is blind .', 'es diu que l amor es cec .'],
#  ['they work eight hours a day .', 'treballen vuit hores al dia .'],
#  ['they re not my real parents .', 'ells no son els meus vertaders pares .'],
#  ['this river s water is clean .', 'l aigua d aquest riu esta neta .'],
#  ['we joined in the discussion .', 'hem participat a la discussio .'],
#  ['we want a peaceful solution .', 'volem una solucio pacifica .'],
#  ['what are you doing tomorrow ?', 'que fas dema ?'],
#  ['what is wrong with that guy ?', 'que li passa a aquet paio ?'],
#  ['when did that happen to you ?', 'quan et va passar allo ?'],
#  ['when did that happen to you ?', 'quan us va passar allo ?'],
#  ['where will we go afterwards ?', 'on anirem despres ?'],
#  ['who are you guys talking to ?', 'amb qui esteu parlant ?'],
#  ['why does racism still exist ?', 'per que encara existeix el racisme ?'],
#  ['you can always count on tom .', 'sempre pots confiar en en tomas .'],
#  ['do you know where she s gone ?', 'saps on ha anat ella ?'],
#  ['don t make me wait like this .', 'no em facis esperar aixi .'],
#  ['have you eaten breakfast yet ?', 'ja has esmorzat ?'],
#  ['he decided to become a pilot .', 'va decidir fer se pilot .'],
#  ['he goes to the office by car .', 'va al despatx amb cotxe .'],
#  ['he is the manager of a hotel .', 'es el director d un hotel .'],
#  ['he lost all the money he had .', 'va perdre tots els diners que tenia .'],
#  ['he plays the piano very well .', 'ell toca el piano molt be .'],
#  ['how long will this cold last ?', 'quant de temps durara aquesta fred ?'],
#  ['how much is this watch worth ?', 'quant val aquest rellotge ?'],
#  ['i don t want to go on my own .', 'no vull anar hi tot sol .'],
#  ['i don t want to go to school .', 'no vull anar a l escola .'],
#  ['i have something to tell you .', 't he de dir una cosa .'],
#  ['i have something to tell you .', 'us he de dir una cosa .'],
#  ['i have something to tell you .', 'tinc una cosa a dir te .'],
#  ['i must have the wrong number .', 'dec tenir el numero equivocat .'],
#  ['i never get tired of talking .', 'no em canso mai de parlar .'],
#  ['i saw him tear up the letter .', 'el vaig veure estripar la carta .'],
#  ['i will get in touch with you .', 'em posare en contacte amb tu .'],
#  ['i d like to get a head start .',
#   'm agradaria tenir hi avantatge inicial .'],
#  ['i d like to get back to work .', 'm agradaria tornar a la feina .'],
#  ['i ve been really busy lately .', 'he estat molt ocupat recentment .'],
#  ['if you don t eat you ll die .', 'si no menges et mors .'],
#  ['japan is smaller than canada .', 'el japo es mes petit que el canada .'],
#  ['please don t open the window .', 'si us plau no obri la finestra .'],
#  ['she sent you her best wishes .',
#   'ella t envia els seus millors desitjos .'],
#  ['some animals eat their young .',
#   'alguns animals es mengen les seves cries .'],
#  ['that s exactly what happened .', 'aixo es exactament el que va passar .'],
#  ['the crowd rushed to the exit .', 'la gentada va correr cap a la sortida .'],
#  ['the girl didn t say anything .', 'la nena no va dir res .'],
#  ['the soldier gave water to me .', 'el soldat m ha donat aigua .'],
#  ['this is a very common injury .', 'aquesta lesio es molt comu .'],
#  ['tom and mary love each other .',
#   'en tom i la maria s estimen l un a l altra .'],
#  ['tom and mary love each other .',
#   'en tom i la maria s estimen l una a l altre .'],
#  ['tom doesn t know the details .', 'tom no coneix els detalls .'],
#  ['tom enjoyed playing baseball .', 'en tom gaudia de jugar a beisbol .'],
#  ['tom knows time s running out .', 'el tom sap que el temps s acaba .'],
#  ['tom only listens to podcasts .', 'en tom nomes escolta podcasts .'],
#  ['wait here till he comes back .', 'espera aqui fins que ell torni .'],
#  ['we killed time playing cards .', 'matavem el temps jugant a les cartes .'],
#  ['we must control our passions .', 'hem de controlar les nostres passions .'],
#  ['what you think is irrelevant .', 'el que penses es irellevant .'],
#  ['what s your favorite podcast ?', 'quin es el teu podcast preferit ?'],
#  ['why don t you stay for a bit ?', 'us quedeu una estona ?'],
#  ['do you have medical insurance ?', 'teniu asseguranca medica ?'],
#  ['have a good time on your date .', 'passi ho be a la seva cita .'],
#  ['have a good time on your date .', 'passa t ho be en la teva cita .'],
#  ['have a good time on your date .', 'passeu vos ho be en la vostra cita .'],
#  ['have you already eaten dinner ?', 'ja heu sopat ?'],
#  ['he comes here every five days .', 've aqui cada cinc dies .'],
#  ['he left the book on the table .', 'va deixar el llibre sobre la taula .'],
#  ['how many children do you have ?', 'quants fills tens ?'],
#  ['i believe the choice is clear .', 'crec que l eleccio esta clara .'],
#  ['i didn t know you d come back .', 'no sabia que tornaries .'],
#  ['i didn t know you d come back .', 'no sabia que havies tornat .'],
#  ['i didn t know you d come back .', 'no sabia que regressaries .'],
#  ['i didn t know you d come back .', 'no sabia que havies regressat .'],
#  ['i have a son who s an athlete .', 'tinc un fill atleta .'],
#  ['i sent a letter to my parents .', 'vaig enviar una carta als meus pares .'],
#  ['i sent a letter to my parents .', 'envii una carta als meus pares .'],
#  ['i still need to get a haircut .',
#   'encara em fa falta tallar me els cabells .'],
#  ['i study for hours every day .', 'jo estudio hores cada dia .'],
#  ['it was cheaper than i thought .', 'es mes barat del que em vaig pensar .'],
#  ['it s even worse than it looks .', 'es inclus pitjor del que es veu .'],
#  ['it s even worse than it looks .', 'es fins i tot pitjor del que es veu .'],
#  ['let me know whenever you come .', 'quan vinguis fes m ho saber .'],
#  ['most schools are closed today .',
#   'la majoria d escoles avui estan tancades .'],
#  ['my children will come with me .', 'els meus fills vindran amb mi .'],
#  ['my dad died before i was born .',
#   'mon pare va morir abans del meu naixement .'],
#  ['nobody equals him in strength .', 'ningu no li fa ombra .'],
#  ['nobody equals him in strength .', 'ningu no li es rival .'],
#  ['only peace can save the world .', 'nomes la pau pot salvar el mon .'],
#  ['our summer is short but warm .', 'el nostre estiu es curt pero caloros .'],
#  ['she didn t tell me her secret .', 'ella no em va dir el seu secret .'],
#  ['she is giving a party tonight .', 'ella fa una festa aquesta nit .'],
#  ['the price reflects the demand .', 'el preu reflexa la demanda .'],
#  ['the servant cleaned the floor .', 'el servent va netejar el terra .'],
#  ['this eagle s wings are broken .',
#   'les ales d aquesta aguila estan trencades'],
#  ['this is a very strange letter .', 'aquesta es una carta molt estranya .'],
#  ['tom is a bad influence on you .',
#   'en tom es una mala influencia per a tu .'],
#  ['tom teaches french literature .', 'en tom ensenya literatura francesa .'],
#  ['tom used to work in australia .', 'en tom treballava a australia .'],
#  ['tom wants to change the world .', 'en tom vol canviar el mon .'],
#  ['tom was in boston at the time .', 'en aquell moment en tom era a boston .'],
#  ['tom s arm had to be amputated .', 'van haver d amputar el brac al tom .'],
#  ['tom s arm had to be amputated .', 'li van haver d amputar el brac a tom .'],
#  ['what language do you think in ?', 'en quina llengua penses ?'],
#  ['you agree with tom don t you ?', 'estas d acord amb tom no ?'],
#  ['everyone thinks the same thing .', 'tothom pensa la mateixa cosa .'],
#  ['have you already had breakfast ?', 'ja has esmorzat ?'],
#  ['he is a very thoughtful person .', 'es una persona molt considerada .'],
#  ['i don t know when he will come .', 'no se quan vindra .'],
#  ['i don t like it when you swear .', 'no m agrada que digues paraulotes .'],
#  ['i don t like it when you swear .', 'no m agrada que digueu paraulotes .'],
#  ['i don t speak french or german .', 'no parlo ni frances ni alemany .'],
#  ['i don t want to read this book .', 'no vull llegir aquest llibre .'],
#  ['i have breakfast every morning .', 'cada dia esmorzo .'],
#  ['i paid him the money last week .',
#   'li vaig pagar els diners la setmana passada .'],
#  ['i started a new book yesterday .', 'ahir vaig comencar un llibre nou .'],
#  ['i started a new book yesterday .', 'ahir em vaig comencar un llibre nou .'],
#  ['i wish i could buy that guitar .',
#   'com voldria poder comprar aquesta guitarra .'],
#  ['i wish i could buy that guitar .',
#   'm agradaria poder comprar eixa guitarra .'],
#  ['i wish i could buy that guitar .',
#   'tant de bo pogues comprar aquesta guitarra .'],
#  ['i wish i could buy that guitar .',
#   'tant de bo poguera comprar eixa guitarra .'],
#  ['i d like to give you something .', 'm agradaria donar te alguna cosa .'],
#  ['i d like to stay for one night .', 'm agradaria quedar me aqui una nit .'],
#  ['i m very glad to see you again .',
#   'estic molt content de tornar te a veure .'],
#  ['iron is used for ship building .',
#   'el ferro s usa per a construir vaixells .'],
#  ['is there anything tom won t do ?', 'hi ha res que el tom no faci ?'],
#  ['is there anything tom won t do ?', 'hi ha res que el tom no faria ?'],
#  ['life has become very difficult .', 'la vida s ha tornat molt dificil .'],
#  ['my hobby is listening to music .', 'el meu hobby es escoltar musica .'],
#  ['please circle the right answer .',
#   'encercleu la resposta correcta sisplau .'],
#  ['the cows looked big and docile .', 'les vaques semblaven grans i docils .'],
#  ['the leaves fell from the trees .', 'les fulles caigueren dels arbres .'],
#  ['the leaves fell from the trees .', 'les fulles queien dels arbres .'],
#  ['there s nobody at the entrance .', 'no hi ha ningu a l entrada .'],
#  ['this book is missing two pages .',
#   'a aquest llibre li falten dues pagines .'],
#  ['this is extremely hard for tom .',
#   'aixo es extremadament dificil per a en tom .'],
#  ['tom doesn t like confrontation .',
#   'a en tom no li agrada la confrontacio .'],
#  ['tom got escorted off the plane .', 'van escortar el tom fora de l avio .'],
#  ['was tom in history class today ?',
#   'estava el tom a classe d historia avui ?'],
#  ['why are you not in your office ?', 'per que no estas a la teua oficina ?'],
#  ['all my friends have girlfriends .', 'tots els meus amics tenen xicotes .'],
#  ['can you do anything to help tom ?', 'pots ajudar el tom d alguna forma ?'],
#  ['can you do anything to help tom ?', 'podeu ajudar el tom d alguna forma ?'],
#  ['can you do anything to help tom ?', 'pots fer res per ajudar el tom ?'],
#  ['can you do anything to help tom ?', 'podeu fer res per ajudar el tom ?'],
#  ['did you enjoy reading this book ?', 'has gaudit llegint el llibre ?'],
#  ['do you have to go anywhere else ?', 'que has d anar a cap altre lloc ?'],
#  ['he had a firm belief in his god .', 'te una creenca ferma en deu .'],
#  ['he is getting better bit by bit .', 'ell s esta millorant poc a poc'],
#  ['he is getting better bit by bit .', 'esta millorant poc a poc .'],
#  ['he told me an interesting story .',
#   'm ha contat una historia interessant .'],
#  ['helen keller was deaf and blind .', 'hellen keller era sorda i cega .'],
#  ['how much does he earn per month ?', 'quant guanya al mes ?'],
#  ['i can repeat it again and again .', 'puc repetir ho vint vegades .'],
#  ['i caught the ball with one hand .', 'vaig agafar la pilota amb una ma .'],
#  ['i don t want to do that for tom .', 'no vull fer ho per a en tom .'],
#  ['i heard him sing at the concert .', 'el vaig sentir cantant al concert .'],
#  ['i need that as soon as possible .',
#   'ho necessito tan aviat com sigui possible .'],
#  ['i was not aware of his presence .',
#   'jo no era conscient que ell estava al davant .'],
#  ['i m a professional photographer .', 'jo soc fotograf professional .'],
#  ['i ve still got to take my pills .',
#   'encara haig de prendre m les meves pildores .'],
#  ['it snowed from monday to friday .', 'va nevar de dilluns a divendres .'],
#  ['let me know when he will arrive .', 'ja em diras quan arriba .'],
#  ['please send us more information .', 'sisplau mandi ns mes informacio .'],
#  ['she dumped him for a richer man .',
#   'ella va abandonar lo per un home mes ric .'],
#  ['she made the same mistake again .',
#   'ella va cometre una altra vegada la mateixa errada .'],
#  ['she will have a baby next month .',
#   'ella vol tenir un fill el mes vinent .'],
#  ['thanks a lot for the invitation .', 'moltes gracies per la invitacio .'],
#  ['the food didn t taste very good .', 'el menjar no tenia gaire bon gust .'],
#  ['the food didn t taste very good .', 'el menjar no feia gaire bon gust .'],
#  ['the new furniture arrived today .', 'el nou mobiliari ha arribat avui .'],
#  ['the sun appeared on the horizon .', 'el sol apareix a l horitzont .'],
#  ['the sun appeared on the horizon .', 'el sol aparegue a l horitzo .'],
#  ['the sun gives us heat and light .', 'el sol ens dona calor i llum .'],
#  ['the sun is larger than the moon .', 'el sol es mes gran que la lluna .'],
#  ['they are at broadway avenue .',
#   'ells estan a l avinguda broadway numero .'],
#  ['this sparrow s wings are broken .',
#   'les ales d aquest pardal estan trencades .'],
#  ['this sparrow s wings are broken .',
#   'les ales d aquest teuladi estan trencades .'],
#  ['this swallow s wings are broken .',
#   'les ales d aquesta oroneta estan trencades .'],
#  ['tom is too young to drive a car .',
#   'tom es massa jove per portar un cotxe .'],
#  ['tom says he s never owned a car .',
#   'el tom diu que mai ha tingut un cotxe .'],
#  ['tom was fired for a good reason .',
#   'tom va ser despedit per una causa justa .'],
#  ['we have a french exam on monday .',
#   'tenim un examen de frances el dilluns .'],
#  ['what did you think of the movie ?', 'que t ha semblat la pel licula ?'],
#  ['you don t have to kick yourself .', 'no et facis mala sang .'],
#  ['you should ve told me yesterday .', 'm ho hauries d haver dit ahir .'],
#  ['you re still too young to drink .', 'encara ets massa jove per a beure .'],
#  ['your opinion is important to me .',
#   'la teua opinio es important per a mi .'],
#  ['asians generally have black hair .',
#   'els asiatics normalment tenen el cabell negre '],
#  ['do you know who wrote this novel ?',
#   'saps qui va escriure aquesta novela ?'],
#  ['do you know who wrote this novel ?',
#   'sabeu qui va escriure aquesta novel la ?'],
#  ['don t compare me to a movie star .',
#   'no em comparis amb una estrella de cinema .'],
#  ['have you already eaten breakfast ?', 'ja has esmorzat ?'],
#  ['have you eaten breakfast already ?', 'ja has esmorzat ?'],
#  ['he must have reached the station .', 'ell deu haver arribar a l estacio .'],
#  ['he went skiing during the winter .', 'se n va anar a esquiar a l hivern .'],
#  ['how long have you had a headache ?',
#   'fa quant de temps que et fa mal el cap ?'],
#  ['how much does he earn in a month ?', 'quant guanya al mes ?'],
#  ['i recognized him at first glance .', 'l he reconegut a primer cop d ull .'],
#  ['i saw the moon above the horizon .', 'veig la lluna sobre l horitzont .'],
#  ['in the alphabet b comes after a .',
#   'en l abecedari la be va despres de la a .'],
#  ['my brother in law is a policeman .', 'el meu cunyat es policia .'],
#  ['my father died before i was born .',
#   'mon pare va morir abans del meu naixement .'],
#  ['my father died before i was born .',
#   'mon pare va morir abans que jo nasquera .'],
#  ['my father died before i was born .',
#   'el meu pare va morir abans de neixer jo .'],
#  ['please answer the question again .',
#   'si us plau respongui un altre cop a la pregunta .'],
#  ['ten years is a long time to wait .',
#   ' anys es un llarg temps per esperar .'],
#  ['the bus arrived ten minutes late .', 'el bus va arribar deu minuts tard .'],
#  ['the bus arrived ten minutes late .', 'l autobus arriba deu minuts tard .'],
#  ['the bus arrived ten minutes late .',
#   'l autobus va arribar amb deu minuts de retard .'],
#  ['the flood caused a lot of damage .', 'la riada va fer molt de mal .'],
#  ['the flood caused a lot of damage .', 'la inundacio va fer molt de mal .'],
#  ['the policewoman directed traffic .', 'la policia dirigia el transit .'],
#  ['the policewoman directed traffic .',
#   'l agent de policia dirigia el transit .'],
#  ['the rumor is true to some extent .',
#   'fins a un cert punt el rumor es cert .'],
#  ['thinking is talking with oneself .', 'pensar es parlar amb un mateix .'],
#  ['tom and mary acted like children .',
#   'en tom i la mary es portaven com nens .'],
#  ['tom couldn t hold back his tears .',
#   'tom no va poder contenir les llagrimes .'],
#  ['tom couldn t hold back his tears .',
#   'tom no podia contenir les llagrimes .'],
#  ['tom doesn t go to school anymore .', 'tom ja no va a l escola .'],
#  ['tom doesn t like how mary laughs .',
#   'a en tomas no li agrada com riu la maria .'],
#  ['tom is no longer studying french .', 'en tom ja no estudia frances .'],
#  ['tom took out a pen and a notepad .',
#   'en tom va treure un boligraf i un bloc de notes .'],
#  ['tom was walking in front of mary .', 'el tom caminava davant la mary .'],
#  ['when can we see each other again ?', 'on ens podem tornar a veure ?'],
#  ['why don t you sit down and relax ?', 'per que no et sentes i et relaxes ?'],
#  ['you treated me like a little kid .', 'em vas tractar com a un nen petit .'],
#  ['you treated me like a little kid .',
#   'em vas tractar com a una nena petita .'],
#  ['you treated me like a little kid .',
#   'em vas tractar com si fos un nen petit .'],
#  ['you treated me like a little kid .',
#   'em vas tractar com si fos una nena petita .'],
#  ['are we talking about the same tom ?', 'estem parlant del mateix tom ?'],
#  ['are we talking about the same tom ?', 'parlem del mateix tom ?'],
#  ['both men apologized to each other .',
#   'tots dos homes es van disculpar entre ells .'],
#  ['can you see that house over there ?', 'veus la caseta d alla ?'],
#  ['everyone hoped that she would win .', 'tothom esperava que guanyes .'],
#  ['get me something to drink please .',
#   'doni m alguna cosa per beure si us plau .'],
#  ['he was willing to work for others .',
#   'ell estava disposat a treballar per altres .'],
#  ['how many questions did you answer ?', 'quantes preguntes has contestat ?'],
#  ['i burned my fingers on a hot iron .',
#   'em vaig cremar els dits amb un ferro roent .'],
#  ['i burned my fingers on a hot iron .',
#   'em vaig cremar els dits amb una planxa calenta .'],
#  ['i have nothing in common with her .', 'no tinc res en comu amb ella .'],
#  ['i just want you to leave me alone .', 'nomes vull que em deixis en pau .'],
#  ['i spend money as soon as i get it .',
#   'em gasto els diners de seguida que en tinc .'],
#  ['i wonder what s going on in there .',
#   'em pregunto que esta passant alla dins .'],
#  ['i write letters that i never send .', 'escric cartes que no envio mai .'],
#  ['i write to my mother once a month .',
#   'escric a la meva mare un cop al mes .'],
#  ['i d like to give this to you tom .', 'm agradaria donar te aixo tom .'],
#  ['i d like to go back to the office .', 'm agradaria tornar a la oficina .'],
#  ['is flight going to be delayed ?', 'el vol te retard ?'],
#  ['last night we worked until p .m .',
#   'ahir a la nit varem treballar fins a les deu .'],
#  ['many people eat three meals a day .',
#   'molta gent menja tres apats al dia .'],
#  ['my father retired at years old .', 'mon pare es va jubilar als anys .'],
#  ['my mother knows how to make cakes .',
#   'la meva mare sap com fer pastissos .'],
#  ['tell me your plans for the future .',
#   'explica m els teus plans per al futur .'],
#  ['tell me your plans for the future .', 'conta m els teus plans de futur .'],
#  ['tell me your plans for the future .',
#   'expliqueu me els vostres plans per al futur .'],
#  ['thank you so much for inviting me .', 'moltes gracies per la invitacio .'],
#  ['that pair of pliers came in handy .',
#   'aquelles alicates em van ser molt utils .'],
#  ['that was a very risky thing to do .',
#   'era una cosa molt arriscada de dur a terme .'],
#  ['there s a dictionary on the table .', 'hi ha un diccionari a la taula .'],
#  ['today s meeting has been canceled .',
#   'la reunio d avui ha sigut cancelada .'],
#  ['tom is calling from his cellphone .',
#   'en tom truca des del seu telefon mobil .'],
#  ['tom is such a good french speaker .', 'en tom es un francofon tan bo .'],
#  ['tom never told us why he did that .',
#   'en tom mai no ens va dir per que ho havia fet .'],
#  ['tom studied literature in college .',
#   'en tom va estudiar literatura a la universitat .'],
#  ['tom was too frightened to do that .',
#   'en tom estava massa esgarrifat per a fer allo .'],
#  ['tom s father is older than mary s .',
#   'el pare d en tom es mes gran que el de la mary .'],
#  ['we don t know why he had to leave .',
#   'no sabem per que va haver de marxar .'],
#  ['we have a french test next monday .',
#   'tenim un examen de frances el dilluns .'],
#  ['we re sorry for the inconvenience .', 'ens sap greu la molestia causada .'],
#  ['where s the nearest travel agency ?',
#   'on es l agencia de viatges mes propera ?'],
#  ['why don t you guys stay for a bit ?', 'us quedeu una estona ?'],
#  ['why is fishing not permitted here ?', 'per que esta prohibit pescar aci ?'],
#  ['will you show me your photo album ?',
#   'em mostraras el vostre album de fotos ?'],
#  ['bangkok is thailand s capital city .',
#   'bangkok es la capital de tailandia .'],
#  ['do you want to play tennis with us ?',
#   'vols jugar a tennis amb nosaltres ?'],
#  ['fishing in this lake is prohibited .',
#   'esta prohibit pescar en aquest llac .'],
#  ['he helped poor people all his life .',
#   'ell va ajudar els pobres tota la seva vida .'],
#  ['he studies contemporary literature .',
#   'ell estudia literatura contemporania .'],
#  ['i can t remember where i bought it .',
#   'no puc recordar on el vaig comprar .'],
#  ['i can t remember where i bought it .', 'no recorde on el vaig comprar .'],
#  ['i can t remember where i bought it .', 'no recorde on ho vaig comprar .'],
#  ['i can t remember where i bought it .', 'no recorde on la vaig comprar .'],
#  ['i can t remember where i bought it .',
#   'no me n recorde d on ho vaig comprar .'],
#  ['i can t remember where i bought it .', 'no recordo on el vaig comprar .'],
#  ['i didn t do what i was asked to do .',
#   'no vaig fer el que se m havia demanat .'],
#  ['i didn t know that tom was in town .',
#   'no sabia que en tom era al poble .'],
#  ['i heard a beautiful song yesterday .',
#   'ahir vaig sentir una canco bonica .'],
#  ['i plan to visit boston next summer .',
#   'planifico visitar boston l estiu que ve .'],
#  ['i thanked him for what he had done .', 'li vaig agrair el que va fer .'],
#  ['i d like to forget the whole thing .', 'm agradaria oblidar tot allo .'],
#  ['i d like to get to know tom better .',
#   'm agradaria coneixer millor en tom .'],
#  ['i d like to meet your older sister .',
#   'voldria trobar me amb la teva germana gran .'],
#  ['i d like to meet your older sister .',
#   'm agradaria coneixer la teva germana gran .'],
#  ['i m the one who pays all the bills .',
#   'jo soc qui paga totes les factures .'],
#  ['i m very slow at making up my mind .',
#   'soc molt lent a l hora de prendre decisions .'],
#  ['i too didn t understand anything .', 'jo tampoc entenc res .'],
#  ['is anybody here willing to do that ?', 'algu esta disposat a fer allo ?'],
#  ['is there a post office around here ?',
#   'hi ha alguna oficina postal per aqui ?'],
#  ['is there a post office around here ?',
#   'hi ha alguna oficina de correus prop d aci ?'],
#  ['is there a post office around here ?',
#   'hi ha per aci alguna oficina de correus ?'],
#  ['music surrounds our lives like air .',
#   'la musica envolta les nostres vides com ho fa l aire .'],
#  ['only adults are allowed to do that .',
#   'nomes els adults tenen permis per fer allo .'],
#  ['switzerland is a beautiful country .', 'suissa es un pais molt bonic .'],
#  ['the door is locked at nine o clock .',
#   'la porta es tanca amb clau a les nou .'],
#  ['the elevator is out of order today .', 'l ascensor no funciona avui .'],
#  ['the lion is the king of the jungle .', 'el lleo es el rei de la selva .'],
#  ['the situation is beyond my control .',
#   'la situacio es mes enlla del meu control .'],
#  ['these questions are easy to answer .',
#   'aquestes preguntes son facils de respondre .'],
#  ['they all looked for the lost child .', 'tots buscaven el nen perdut .'],
#  ['tom and mary sang a christmas song .',
#   'en tom i la maria van cantar una canco de nadal .'],
#  ['tom couldn t find the light switch .',
#   'en tom no podia trobar l interruptor del llum .'],
#  ['tom is much taller than i expected .',
#   'el tom es molt mes alt del que m esperava .'],
#  ['tom wasn t sure where he should go .',
#   'en tom no estava segur d on hauria d anar .'],
#  ['we are sorry for the inconvenience .',
#   'ens sap greu la molestia causada .'],
#  ['we ll show you how to catch a fish .',
#   't ensenyarem com atrapar un peix .'],
#  ['we re not going to change anything .', 'no canviarem res .'],
#  ['we re not here to play or have fun .',
#   'no estem aqui per jugar ni per divertir nos .'],
#  ['what little money i had was stolen .',
#   'els pocs diners que tenia me ls van robar .'],
#  ['you said that the other day right ?', 'aixo vas dir l altre dia no ?'],
#  ['a lot of jobs are done by computers .',
#   'moltes feines les fan els ordinadors .'],
#  ['do you wonder why no one trusts him ?', 't estranya que ningu hi confii ?'],
#  ['don t go to sleep with the light on .', 'no et durmis amb el llum ences .'],
#  ['how do you deal with writer s block ?',
#   'com treballes el teu bloqueig escriptor ?'],
#  ['how much money does he make a month ?', 'quant guanya al mes ?'],
#  ['i can t remember which is my racket .',
#   'no recorde quina es la meua raqueta .'],
#  ['i don t think we can take that risk .',
#   'crec que no podem correr aquest risc .'],
#  ['i don t think we can take that risk .',
#   'crec que no podem correr eixe risc .'],
#  ['i don t want to waste a moment more .', 'no vull perdre un instant mes .'],
#  ['i have nothing to say to any of you .',
#   'no tinc res a dir vos a cap de vosaltres .'],
#  ['i know that tom is in australia now .',
#   'se que en tom es a australia ara mateix .'],
#  ['i thought that i saw someone i knew .',
#   'em pensava que havia vist algu que coneixia .'],
#  ['i was caught in a shower on the way .',
#   'm ha enxampat un xafec pel cami .'],
#  ['i d like to get you both to help me .',
#   'm agradaria que tots dos m ajudessiu .'],
#  ['i d like to get you both to help me .',
#   'm agradaria que ambdos m ajudessiu .'],
#  ['i d like to reserve a table for two .',
#   'm agradaria reservar una taula per a dos .'],
#  ['i d like to stay here for one night .',
#   'm agradaria quedar me aqui una nit .'],
#  ['is there any other way to get there ?',
#   'hi ha alguna altra manera d arribar alla ?'],
#  ['look that word up in the dictionary .',
#   'cerca aquella paraula al diccionari .'],
#  ['my apartment is on the fourth floor .',
#   'el meu apartament esta al quart pis .'],
#  ['night is when most people go to bed .',
#   'la nit es quan la majoria de la gent se n va al llit .'],
#  ['take this medicine before each meal .',
#   'preneu aquest medicament abans de cada apat .'],
#  ['the body hasn t yet been identified .', 'el cos no ha estat identificat .'],
#  ['the boy asked his mother a question .',
#   'el nen li feu una pregunta a la seva mare .'],
#  ['the teacher told me to study harder .',
#   'el professor em va dir que estudies molt .'],
#  ['tom had acne when he was a teenager .',
#   'en tom tenia acne quan era adolescent .'],
#  ...]

# %%
# !python train.py --epoch=20000 --lr=0.0005
# Out:
# 141543 translation pairs found in dataset.
# Reduced dataset to 141437 translation pairs.
# No of words in each language:
# eng 13751
# spa 26844
# Starting Training Loop...
# 1m 38s (- 4m 54s) (5000 25%) 5.3793
# 3m 24s (- 3m 24s) (10000 50%) 5.1086
# 5m 10s (- 1m 43s) (15000 75%) 4.9944
# 7m 0s (- 0m 0s) (20000 100%) 5.0008

# %%
# !python translate.py --translate_sentence='I am hungry!'
# Out:
# 141543 translation pairs found in dataset.
# Reduced dataset to 141437 translation pairs.
# No of words in each language:
# eng 13751
# spa 26844
# I am hungry!
# input = i am hungry !
# output =  que que de la ? <EOS>

# %%
# !python translate.py --translate_sentence='This is my sister!'
# Out:
# 141543 translation pairs found in dataset.
# Reduced dataset to 141437 translation pairs.
# No of words in each language:
# eng 13751
# spa 26844
# This is my sister!
# input = this is my sister !
# output =  que que que ? ? <EOS>

# %%
# !python translate.py --translate_sentence='Really?'
# Out:
# 1375 translation pairs found in dataset.
# Reduced dataset to 1375 translation pairs.
# No of words in each language:
# eng 1469
# cat 1822
# Really?
# input = really ?
# output = que que ? ? <EOS>

# %%
#I want to make a validation

# !python validate.py --n_iters=1000
# Out:
# python: can't open file 'validate.py': [Errno 2] No such file or directory
